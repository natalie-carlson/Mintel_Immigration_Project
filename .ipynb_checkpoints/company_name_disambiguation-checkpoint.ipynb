# %% [markdown]
# # Mintel Database Company Name Disambiguation
# This notebook attempts to standardize company names from the Mintel Product Database with a fuzzy matching strategy.

# %% [markdown]
# ## Reading in and Checking Data

# %%
# import packages
import pandas as pd
import numpy as np
import re
import nltk
from fuzzywuzzy import fuzz
from sklearn import cluster

# %%
# read in company data
companies = pd.read_csv('/Users/ncarlson/Dropbox/Mintel Immigration Project/GNPD-2009-19.csv', encoding = "cp1252")
# print head of file
print(companies[1:15])
# Out:
#              Ultimate Company                    Company  \
# 1                          22                         22
# 2                          30                         30
# 3                          31                         31
# 4                         899                        899
# 5                         999                        999
# 6                         999                        999
# 7                        1701                       1701
# 8                        1907                       1907
# 9                        2376                       2376
# 10                     232605                     232605
# 11   Hong Guan Kamtai (China)   Hong Guan Kamtai (China)
# 12           Êxito Naturavene           Êxito Naturavene
# 13                     Ñaming                     Ñaming
# 14                     Ñapi-ú                     Ñapi-ú
#
#                                       Company address Company county/State  \
# 1      40 Vu Xuan Thieu, Sai Dong, Long Bien, Hanoi,                   NaN
# 2                                                 NaN                  NaN
# 3                                                 NaN                  NaN
# 4                                                 NaN                  NaN
# 5                                                 NaN                  NaN
# 6                                                 NaN                  NaN
# 7                                                 NaN                  NaN
# 8                                                 NaN                  NaN
# 9                                                 NaN                  NaN
# 10         PO Box 1025, Mississauga, Ontario, L4Y 3W3              Ontario
# 11                                                NaN                  NaN
# 12         Rua Prof. Miguel Russiano 320, Sao Paulo,                   NaN
# 13  Pol. Ind. El Zafranar, Parcelas 21.1 y 21.2, M...                  NaN
# 14      Tucumán 845, Corrientes, Bella Vista, W342CYQ                  NaN
#
#    Company Territory         Website
# 1            Vietnam             NaN
# 2             Poland             NaN
# 3          Indonesia             NaN
# 4          Indonesia             NaN
# 5              China             NaN
# 6          Indonesia             NaN
# 7       South Africa  www.1701.co.za
# 8        New Zealand             NaN
# 9          Indonesia             NaN
# 10            Canada             NaN
# 11               NaN             NaN
# 12            Brazil             NaN
# 13             Spain  www.n-aming.es
# 14         Argentina   www.napiu.com

# %%
# number of unique companies
len(pd.unique(companies['Ultimate Company']))
# Out:
# 197175

# %%
# smaller subset of data to test code
companies_sample = companies.sample(n=10000)

# %% [markdown]
# ## Data Cleaning and Processing
# Next, we'll clean and preprocess the company names.

# %%
# function for removing special characters
def clean_special_characters(txt):
    seps = [' ','`','~','!','@','#','$','%','^','&','*','(',')','_','-','+','=','{','[','}','}','|',':',';','<',',','>','.','?','/']
    default_sep = seps[0]
    
    for sep in seps[1:]:
            txt = txt.replace(sep, default_sep)
    re.sub(' +', ' ', txt)
    temp_list = [i.strip() for i in txt.split(default_sep)]
    temp_list = [i for i in temp_list if i]
    return ' '.join(temp_list)

# %%
# function for removing stopwords -- using nltk english default for now
from nltk.corpus import stopwords
print(stopwords.words('english'))
my_stopwords = stopwords.words('english')

def clean_stopwords(txt):
    temp_list = txt.split(' ')
    temp_list = [i for i in temp_list if i not in my_stopwords]
    return ' '.join(temp_list)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# data cleaning function -- putting the previous two together 
def data_cleaning(data, nameCol='Ultimate Company'):
    data.dropna(subset=[nameCol], inplace=True)
    data = data.rename_axis('CompanyID').reset_index()
    data_clean = data.copy()
    data_clean['CompanyName_clean'] = data_clean[nameCol].apply(lambda x: x.lower())
    data_clean['CompanyName_clean'] = data_clean['CompanyName_clean'].apply(clean_special_characters)
    data_clean['CompanyName_clean'] = data_clean['CompanyName_clean'].apply(clean_stopwords)
    data_clean = data_clean.sort_values(by=['CompanyName_clean'])
    return(data_clean)

# %%
# run data cleaning function on our data
companies_clean = data_cleaning(companies_sample, nameCol='Ultimate Company')
print(len(companies_clean))
# remove empty company names
companies_clean = companies_clean[companies_clean['CompanyName_clean']!='']
print(len(companies_clean))
# Out:
# 10000
# 9995

# %%
print(companies_clean[100:150])
# Out:
#      CompanyID                                   Ultimate Company  \
# 100      24595                                       Bhole Bakery
# 469      25062                                               BIJA
# 237      25429                               Bio Collections Plus
# 438      25456                                     Bio Fair Trade
# 460      25567                                           Bio Sito
# 684      25586                             Bio Tree Biotechnology
# 914      25732                                               Bio3
# 808      26129                                          Biokarpos
# 137      26399                                 Bioptik Technology
# 807      26411                                             Bioray
# 84       26455                                             Biosan
# 260      26616                              Bioucan Biotechnology
# 598      26631                                     Biovena Health
# 823      26923                                Biscottificio Cervo
# 796      26968                               Biscuiterie Augereau
# 555      27166                                          Bistrotea
# 859      27559                                    Bleach Products
# 181      28241                                             Bo Mei
# 649      28589                                       Bodegas Peru
# 927      28611                               Bodegas Santa Silvia
# 682      28824                               Boehringer Ingelheim
# 786      29020                      Bolgrads'kyy Syrorobnyy Zavod
# 686      29223                                            Bon-Bon
# 187      29325                                          Bonduelle
# 616      29415                           Bonkers Performance Teas
# 815      29491                                     Bontà Emiliane
# 59       29618                                            boozeME
# 530      30037                                        Boulangerie
# 470      30085                    Boulder Canyon Customer Service
# 791      30113                                          Bountiful
# 269      30654                                   Brasserie Beau's
# 998      30621                         Brasília Produtos Naturais
# 450      31342                                Bright Food (Group)
# 660      31694                                  Brooklyn Bottling
# 483      31761                                    Brothers Irvine
# 93      215779                              The Buckley's Company
# 179      32656                            Burca's Abastecimientos
# 365      32879                                      Butter London
# 282      18231                                      Bünting Group
# 364     100753                                             I.C.S.
# 828     100763                                     I.D.C. Hungary
# 300      33500                                C&O Pharmaceuticals
# 101      34075                                            Cai Tai
# 471      34084                                      Cai Yi Beauty
# 395      34351                                 California Rancher
# 516      34526                                  Camenae Cosmetics
# 952      34590                                            Camorak
# 36       34629                                      Campbell Soup
# 434      34695                                  Campisi Salvatore
# 951      34720  Campo Verde Distribuidora de Gêneros Alimentícios
#
#                                                Company  \
# 100                                       Bhole Bakery
# 469                                               BIJA
# 237                               Bio Collections Plus
# 438                                     Bio Fair Trade
# 460                                           Bio Sito
# 684                             Bio Tree Biotechnology
# 914                                               Bio3
# 808                                          Biokarpos
# 137                                 Bioptik Technology
# 807                                             Bioray
# 84                                              Biosan
# 260                              Bioucan Biotechnology
# 598                                     Biovena Health
# 823                                Biscottificio Cervo
# 796                               Biscuiterie Augereau
# 555                                          Bistrotea
# 859                                    Bleach Products
# 181                                             Bo Mei
# 649                                       Bodegas Peru
# 927                               Bodegas Santa Silvia
# 682                               Boehringer Ingelheim
# 786                      Bolgrads'kyy Syrorobnyy Zavod
# 686                                            Bon-Bon
# 187                                          Bonduelle
# 616                           Bonkers Performance Teas
# 815                                     Bontà Emiliane
# 59                                             boozeME
# 530                                        Boulangerie
# 470                    Boulder Canyon Customer Service
# 791                                          Bountiful
# 269                                   Brasserie Beau's
# 998                         Brasília Produtos Naturais
# 450                                           Weetabix
# 660                                  Brooklyn Bottling
# 483                                    Brothers Irvine
# 93                               The Buckley's Company
# 179                            Burca's Abastecimientos
# 365                                      Butter London
# 282                          Krone Handelsgesellschaft
# 364                                             I.C.S.
# 828                                     I.D.C. Hungary
# 300                                C&O Pharmaceuticals
# 101                                            Cai Tai
# 471                                      Cai Yi Beauty
# 395                                 California Rancher
# 516                                  Camenae Cosmetics
# 952                                            Camorak
# 36                                          Campbell's
# 434                                  Campisi Salvatore
# 951  Campo Verde Distribuidora de Gêneros Alimentícios
#
#                                        Company address Company county/State  \
# 100  Nr. Sindh Petrol Pump, Fruit Market, Opp. Anar...                  NaN
# 469                 Bellingham, Washington (WA), 98225      Washington (WA)
# 237         Jl. Biak No. 18A, Jakarta Pusat, Jakarta,                   NaN
# 438                    Lövöház u. 20/a, Budapest, 1024                  NaN
# 460                    St.Varvaras 33, Aigaleo, 122 44                  NaN
# 684  ST72A Jln Tunas Baru Seksyen 2/7, Kaw. Perind....                  NaN
# 914  8000 S.W., 68th Terrace, Miami, Florida (FL), ...         Florida (FL)
# 808           12th km. Argos-Sterna, Malantreni, 21200                  NaN
# 137  1F, 9, Kong-Yei E. 4th Rd., Hsinchu Industrial...                  NaN
# 807                                     Laguna Hills,                   NaN
# 84                        Mohed 6604, Söderala, 826 92                  NaN
# 260  No. 14, An Lin Road,, Yen Chao Dist., Kaohsiung,                   NaN
# 598                  ul. Odrowaza 15, Warszawa, 03-310                  NaN
# 823                    Via della Vittoria 27, Biella,                   NaN
# 796               Zone Artisanale, Saint-Benoît, 86280                  NaN
# 555  5 Church Road, Burgess Hill, West Sussex, RH159BB                  NaN
# 859                 10 Redchurch Street, London, E27DD                  NaN
# 181                                        Guangzhou,                   NaN
# 649            Av. General Garzón 1283 Of. 509, Lima,                   NaN
# 927                                    San Juan, 72952                  NaN
# 682                                PB 405, Asker, 1371                  NaN
# 786  Zavods'ka 79 Street, Odes'ka Oblast', Bolgrad,...                  NaN
# 686                     Toms Allé 1, Ballerup, DK-2750                  NaN
# 187                   38 rue de l'avenir, Genas, 69740                  NaN
# 616  9765-202 Bowline Drive, West Palm Beach, Flori...         Florida (FL)
# 815                     Via S. Orsola 2/A, Correggio,                   NaN
# 59                       Goerzallee 299, Berlin, 14167                  NaN
# 530                                                NaN                  NaN
# 470  643 N, 98th St. no. 133, Omaha, Nebraska (NE),...        Nebraska (NE)
# 791                    Postbus 185, Groesbeek, 6560 AD                  NaN
# 269                           Vankleek Hill, Ontario,               Ontario
# 998  Q. SES - Qd 11 - Lote 16, Setor Economico de S...                  NaN
# 450     Burton Latimer, Northants, Kettering, NN15 5JR                  NaN
# 660                       Milton, New York (NY), 12547        New York (NY)
# 483                   Plant, California (CA), CA 92614      California (CA)
# 93                       Mississauga, Ontario, L5N 2X7              Ontario
# 179  Calle Juan Pable II No. 620, Urb. Las Brisas C...                  NaN
# 365                    Seattle, Washington (WA), 98121      Washington (WA)
# 282                                        Leer, 26789                  NaN
# 364            Area ASI, Loc. Pascarola-Caivano (NA),                   NaN
# 828            Leshegy utca 3, Szigetszentmiklós, 2310                  NaN
# 300  C-009, Enugu Plaza, Trade Fair Complex, Badaga...                  NaN
# 101  505, No.747, Jinghan Avenue, Jianghan District...                Hubei
# 471           5F-1, No. 288-4, Xin-Yia St, Kaohsiung,                   NaN
# 395               El Segundo, 90245, California (CA),       California (CA)
# 516  2101-1-103 Sport Road West, Tianhe District, G...            Guangdong
# 952  Via Della Tecninca 73, San Lazzaro di Savena, ...                  NaN
# 36   Km 291, 5 Carr. México-Cd. Juárez, Villagrán, ...                  NaN
# 434             C.da Lettiera, Sicilia, Pachino, 96018                  NaN
# 951        Rua Mesquita, 75, Cambuci, São Paulo - SP,                   NaN
#
#     Company Territory                           Website  \
# 100             India                               NaN
# 469               USA                               NaN
# 237         Indonesia                               NaN
# 438           Hungary                               NaN
# 460            Greece                               NaN
# 684          Malaysia                               NaN
# 914               USA                      www.bio3.com
# 808            Greece                               NaN
# 137            Taiwan                               NaN
# 807               USA                               NaN
# 84             Sweden                               NaN
# 260            Taiwan                               NaN
# 598            Poland                               NaN
# 823             Italy         www.biscottificiocervo.it
# 796            France       www.bicsuiterie-augereau.fr
# 555                UK       http://www.bistro-tea.co.uk
# 859                UK            www.bleachlondon.co.uk
# 181             China                               NaN
# 649              Peru                               NaN
# 927         Argentina                               NaN
# 682            Norway                               NaN
# 786           Ukraine                      bsrz@ukr.net
# 686           Denmark  www.bonbon.dk; www.tomsgroup.com
# 187            France                 www.bonduelle.com
# 616               USA         http://www.bonkerstea.com
# 815             Italy                               NaN
# 59            Germany             www.kukkicocktail.com
# 530            Canada                               NaN
# 470               USA        www.bouldercanyonfoods.com
# 791       Netherlands                  www.bountiful.nl
# 269            Canada                               NaN
# 998            Brazil                               NaN
# 450                UK                www.weetabix.co.uk
# 660               USA                               NaN
# 483               USA                               NaN
# 93             Canada                  www.buckleys.com
# 179              Peru     www.abastecimientosburcas.com
# 365               USA              www.butterlondon.com
# 282           Germany                  www.naturwert.de
# 364             Italy                    www.icsfood.it
# 828           Hungary                               NaN
# 300           Nigeria                               NaN
# 101             China                               NaN
# 471            Taiwan                               NaN
# 395               USA                               NaN
# 516             China                               NaN
# 952             Italy                               NaN
# 36             Mexico              www.campbells.com.mx
# 434             Italy            www.campisiconserve.it
# 951            Brazil          www.campoverdedga.com.br
#
#                                      CompanyName_clean
# 100                                       bhole bakery
# 469                                               bija
# 237                               bio collections plus
# 438                                     bio fair trade
# 460                                           bio sito
# 684                             bio tree biotechnology
# 914                                               bio3
# 808                                          biokarpos
# 137                                 bioptik technology
# 807                                             bioray
# 84                                              biosan
# 260                              bioucan biotechnology
# 598                                     biovena health
# 823                                biscottificio cervo
# 796                               biscuiterie augereau
# 555                                          bistrotea
# 859                                    bleach products
# 181                                             bo mei
# 649                                       bodegas peru
# 927                               bodegas santa silvia
# 682                               boehringer ingelheim
# 786                      bolgrads'kyy syrorobnyy zavod
# 686                                            bon bon
# 187                                          bonduelle
# 616                           bonkers performance teas
# 815                                     bontà emiliane
# 59                                             boozeme
# 530                                        boulangerie
# 470                    boulder canyon customer service
# 791                                          bountiful
# 269                                   brasserie beau's
# 998                         brasília produtos naturais
# 450                                  bright food group
# 660                                  brooklyn bottling
# 483                                    brothers irvine
# 93                                   buckley's company
# 179                            burca's abastecimientos
# 365                                      butter london
# 282                                      bünting group
# 364                                                  c
# 828                                          c hungary
# 300                                  c pharmaceuticals
# 101                                            cai tai
# 471                                      cai yi beauty
# 395                                 california rancher
# 516                                  camenae cosmetics
# 952                                            camorak
# 36                                       campbell soup
# 434                                  campisi salvatore
# 951  campo verde distribuidora de gêneros alimentícios

# %% [markdown]
# ## Fuzzy Matching
# Next, we compute distance using the FuzzyWuzzy library. It's intractable to compute pairwise distance between 200,000^2 matches so we'll group by first character(s) and compute within. We will test out different metrics -- e.g. Levenschtein ratio, partial ratio, etc. -- and different cutoffs to choose the optimal approach. See this guide for more details on the specific ratios: https://www.datacamp.com/community/tutorials/fuzzy-string-python

# %%
# fuzzy matching by group 
from fuzzywuzzy import fuzz


# Levenschtein ratio
all_main_name = pd.DataFrame(columns=['first_characters','names','alias','score'])
all_names = companies_clean['CompanyName_clean'].unique()
all_main_name['names'] = all_names
all_main_name['first_characters'] = all_main_name['names'].apply(lambda x: x[0])
all_sort_gp = all_main_name['first_characters'].unique()

for sortgp in all_sort_gp:
    this_gp = all_main_name.groupby(['first_characters']).get_group(sortgp)
    gp_start = this_gp.index.min()
    gp_end = this_gp.index.max()
    for i in range(gp_start,gp_end+1):
    
        # if self has not got alias, asign to be alias of itself
        if pd.isna(all_main_name['alias'].iloc[i]):
            all_main_name['alias'].iloc[i] = all_main_name['names'].iloc[i]
            all_main_name['score'].iloc[i] = 100
        
        # if the following has not got alias and fuzzy match, asign to be alias of this one
        for j in range(i+1,gp_end+1):
            if pd.isna(all_main_name['alias'].iloc[j]):
                fuzz_score = fuzz.ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
                if (fuzz_score > 85):
                    all_main_name['alias'].iloc[j] = all_main_name['alias'].iloc[i]
                    all_main_name['score'].iloc[j] = fuzz_score

all_main_name.to_csv('/Users/ncarlson/Dropbox/Mintel Immigration Project/Levenschtein.csv')

# Partial ratio
all_main_name = pd.DataFrame(columns=['first_characters','names','alias','score'])
all_names = companies_clean['CompanyName_clean'].unique()
all_main_name['names'] = all_names
all_main_name['first_characters'] = all_main_name['names'].apply(lambda x: x[0])
all_sort_gp = all_main_name['first_characters'].unique()

for sortgp in all_sort_gp:
    this_gp = all_main_name.groupby(['first_characters']).get_group(sortgp)
    gp_start = this_gp.index.min()
    gp_end = this_gp.index.max()
    for i in range(gp_start,gp_end+1):
    
        # if self has not got alias, asign to be alias of itself
        if pd.isna(all_main_name['alias'].iloc[i]):
            all_main_name['alias'].iloc[i] = all_main_name['names'].iloc[i]
            all_main_name['score'].iloc[i] = 100
        
        # if the following has not got alias and fuzzy match, asign to be alias of this one
        for j in range(i+1,gp_end+1):
            if pd.isna(all_main_name['alias'].iloc[j]):
                fuzz_score = fuzz.partial_ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
                if (fuzz_score > 85):
                    all_main_name['alias'].iloc[j] = all_main_name['alias'].iloc[i]
                    all_main_name['score'].iloc[j] = fuzz_score

all_main_name.to_csv('/Users/ncarlson/Dropbox/Mintel Immigration Project/Partial.csv')


# harmonic mean of token set ratio and partial ratio
all_main_name = pd.DataFrame(columns=['first_characters','names','alias','score'])
all_names = companies_clean['CompanyName_clean'].unique()
all_main_name['names'] = all_names
all_main_name['first_characters'] = all_main_name['names'].apply(lambda x: x[0])
all_sort_gp = all_main_name['first_characters'].unique()

for sortgp in all_sort_gp:
    this_gp = all_main_name.groupby(['first_characters']).get_group(sortgp)
    gp_start = this_gp.index.min()
    gp_end = this_gp.index.max()
    for i in range(gp_start,gp_end+1):
    
        # if self has not got alias, asign to be alias of itself
        if pd.isna(all_main_name['alias'].iloc[i]):
            all_main_name['alias'].iloc[i] = all_main_name['names'].iloc[i]
            all_main_name['score'].iloc[i] = 100
        
        # if the following has not got alias and fuzzy match, asign to be alias of this one
        for j in range(i+1,gp_end+1):
            if pd.isna(all_main_name['alias'].iloc[j]):
                s1 = fuzz.partial_ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
                s2 = fuzz.token_set_ratio(all_main_name['names'].iloc[i],all_main_name['names'].iloc[j])
                fuzz_score = 2*s1*s2 / (s1 + s2)
                if (fuzz_score > 85):
                    all_main_name['alias'].iloc[j] = all_main_name['alias'].iloc[i]
                    all_main_name['score'].iloc[j] = fuzz_score

all_main_name.to_csv('/Users/ncarlson/Dropbox/Mintel Immigration Project/Harmonic_Mean.csv')

# %%
print(all_main_name)
#print(all_sort_gp)
# Out:
#      first_characters                        names  \
# 0                   1  1 bakery house com de panif
# 1                   1     10 best foodtech company
# 2                   1        1000 plus enterprises
# 3                   1           1770 spirit nation
# 4                   1                  180 degrees
# ...               ...                          ...
# 4835                ö              ölmühle garting
# 4836                ö                özgörkey gida
# 4837                ø       ødegårdens spisekammer
# 4838                ø                     økoladen
# 4839                ž                ž marausko ii
#
#                             alias score
# 0     1 bakery house com de panif   100
# 1        10 best foodtech company   100
# 2           1000 plus enterprises   100
# 3              1770 spirit nation   100
# 4                     180 degrees   100
# ...                           ...   ...
# 4835              ölmühle garting   100
# 4836                özgörkey gida   100
# 4837       ødegårdens spisekammer   100
# 4838                     økoladen   100
# 4839                ž marausko ii   100
#
# [4840 rows x 4 columns]

# %%
print(all_main_name[all_main_name['score']<100])
# Out:
#      first_characters                                              names  \
# 227                 a                                     aria cosmetics
# 229                 a                                   arkana cosmetics
# 230                 a                                         arla foods
# 247                 a                                artron laboratories
# 264                 a                                         asian food
# 265                 a                                        asian foods
# 613                 c                                            c foods
# 647                 c                                              candy
# 669                 c                                        carjen food
# 868                 c                         comercializadora del llano
# 911                 c                       cooperativa allevatori ovini
# 951                 c                                          cqs foods
# 1047                d                                         debbie dan
# 1091                d                                  dev international
# 1127                d                                distribuidora neksa
# 1161                d                                        dongyu food
# 1235                e                                edlen international
# 1312                e                                 eren international
# 1472                f                                              foods
# 1665                g                goiasminas indústrias de laticínios
# 1692                g                                    gourmet gruppen
# 1786                g                       guangzhou liduo cosmetics co
# 1787                g                          guangzhou oupei cosmetics
# 1904                h                                             hebron
# 1929                h                                               hero
# 2022                i                                     iced beverages
# 2093                i  indústria e comércio de produtos alimentícios ...
# 2114                i                            international cosmetics
# 2235                j                                     jinzixuan food
# 2269                j                               jude's food products
# 2316                k                           kang yuan pharmaceutical
# 2388                k                                     kiss cosmetics
# 2431                k  krk indústria e comércio de produtos alimentícios
# 2433                k                                  ksk food products
# 2499                l                                 laboratorios roble
# 2503                l                                 laboratorios viños
# 2885                m                                              merak
# 2917                m                                            migross
# 3208                n                                            nutrisa
# 3500                p                                           polsnack
# 3514                p                                pound international
# 3738                r                                          rpc foods
# 3814                s                                        sanhui food
# 3848                s                                     sasa cosmetics
# 3997                s                                   sisean cosmetics
# 4423                t                                               tvbg
# 4702                x                                    xiang lan foods
# 4706                x                                        xianji food
# 4707                x                                     xianjing foods
# 4733                y                                         yajia food
#
#                                                   alias score
# 227                                      aqua cosmetics    86
# 229                                      aqua cosmetics    87
# 230                                         arham foods    86
# 247                                   acon laboratories    89
# 264                                            asiafood    89
# 265                                            asiafood    95
# 613                                              c food    92
# 647                                              candly    91
# 669                                          carie food    86
# 868                           comercializadora al grano    86
# 911                              cooperativa allevatori    88
# 951                                              c food    88
# 1047                                          debbe dan    95
# 1091                                   dd international    91
# 1127                                 distribuidora fesa    92
# 1161                                      dong yue food    92
# 1235                            edenworld international    86
# 1312                            edenworld international    92
# 1472                                               food    89
# 1665                 goiasminas indústria de laticínios    99
# 1692                                      gourmet group    86
# 1786                           guangzhou aidu cosmetics    88
# 1787                           guangzhou aidu cosmetics    86
# 1904                                              hebro    91
# 1929                                              hebro    89
# 2022                                      ice beverages    96
# 2093  indústria e comércio de produtos alimentícios ...    87
# 2114                          international cosmeticare    92
# 2235                                   jianzhiyuan food    87
# 2269                                    j food products    86
# 2316                            kang ye pharmaceuticals    89
# 2388                                      kin cosmetics    89
# 2431  kamal indústria e comércio de produtos aliment...    94
# 2433                                    k food products    94
# 2499                                  laboratorios leti    86
# 2503                                laboratorios verkos    86
# 2885                                               mera    89
# 2917                                             migros    92
# 3208                                            nutresa    86
# 3500                                          polisnack    94
# 3514                                 pago international    86
# 3738                                          rcl foods    89
# 3814                                       san hui food    96
# 3848                                        sa cosmetic    88
# 3997                                        sa cosmetic    87
# 4423                                                tvb    86
# 4702                                    xian ling foods    87
# 4706                                         xiang food    86
# 4707                                    xian ling foods    90
# 4733                                        ya jin food    86

# %%
# compute name similarity using fuzzy matching -- harmonic mean of token set ratio and partial ratio
def fuzz_similarity(company_names):
    similarity_array = np.ones((len(company_names), (len(company_names))))*100
    
    for i in range(1, len(company_names)):
        for j in range(i):
            s1 = fuzz.token_set_ratio(company_names[i], company_names[j]) + 0.000000000001
            s2 = fuzz.partial_ratio(company_names[i], company_names[j]) + 0.000000000001
            similarity_array[i][j] = s2
            #similarity_array[i][j] = 2*s1*s2 / (s1 + s2)
    for i in range(len(company_names)):
        for j in range(i + 1, len(company_names)):
            similarity_array[i][j] = similarity_array[j][i]
            
    np.fill_diagonal(similarity_array, 100)
    return(similarity_array)

# %%
# find company clusters with similar names
def company_clusters(data, nameCol = 'Ultimate Company', dropForeign = True):
    data_clean = data_cleaning(data, nameCol = nameCol, dropForeign = dropForeign)
    company_names = data_clean.CompanyName_clean.to_list()
    company_IDs = data_clean.CompanyID.to_list()
    
    similarity_array = fuzz_similarity(company_names)
    clusters = cluster.AffinityPropagation(affinity = 'precomputed').fit_predict(similarity_array)
    df_clusters = pd.DataFrame(list(zip(company_IDs, clusters)), columns = ["CompanyID", "Cluster"])
    
    df_eval = df_clusters.merge(data_clean, on = 'CompanyID', how = 'left')
    return df_eval

# %%
clusters = company_clusters(companies_sample, nameCol = 'Ultimate Company', dropForeign = False)
# Out:
# <ipython-input-22-8e8678ef247c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(subset=[nameCol], inplace=True)
# /Users/ncarlson/Library/Python/3.8/lib/python/site-packages/sklearn/cluster/_affinity_propagation.py:148: FutureWarning: 'random_state' has been introduced in 0.23. It will be set to None starting from 1.0 (renaming of 0.25) which means that results will differ at every function call. Set 'random_state' to None to silence this warning, or to 0 to keep the behavior of versions <0.23.
#   warnings.warn(
# /Users/ncarlson/Library/Python/3.8/lib/python/site-packages/sklearn/cluster/_affinity_propagation.py:246: ConvergenceWarning: Affinity propagation did not converge, this model will not have any cluster centers.
#   warnings.warn("Affinity propagation did not converge, this model "

# %%
clusters = clusters.sort_values(by=['Cluster'])
print(clusters[100:150])
# Out:
#      CompanyID  Cluster                                   Ultimate Company  \
# 695       1695       -1                                        A2B Trading
# 696       1696       -1                                     A2C Intertrade
# 697       1697       -1                       A2P - Alternative 2 Plastics
# 698       1698       -1                                  A2V Farm Organics
# 699       1699       -1                                                A2W
# 700       1700       -1                                A3 Atelier Gourmand
# 701       1701       -1                           A3 Cosmetic Laboratories
# 626       1626       -1                                         A&C Snacks
# 702       1702       -1                                            A3 Wine
# 704       1704       -1                                                A62
# 705       1705       -1                                            A7 Agro
# 706       1706       -1                                        A7B Bohemia
# 707       1707       -1                                             A9 Bio
# 708       1708       -1                                                 AA
# 709       1709       -1                                       AA - Doble A
# 710       1710       -1                                           AA Media
# 711       1711       -1                                        AA Skincare
# 712       1712       -1                                           AA Spice
# 713       1713       -1                                        AA. Doble A
# 714       1714       -1     Ação Beleza Industria e Comércio de Cosmeticos
# 715       1715       -1                      Ação Serviço de Empacotamento
# 716       1716       -1                                   Açúcar Número Um
# 703       1703       -1                                   A4 Fruit Trading
# 748       1748       -1                                  Aache Food Centre
# 625       1625       -1                                         A&C Snacks
# 623       1623       -1                                   A&C Delikatessen
# 533       1533       -1                               A.S. Bawazir Trading
# 534       1534       -1                                      A.S. Bazuhair
# 535       1535       -1                           A.S. Comércio de Cereais
# 536       1536       -1                                 A.S. Narkar & Bros
# 537       1537       -1                                         A.S. Trade
# 538       1538       -1                                       A.S. Traders
# 539       1539       -1                                        A.S. Watson
# 540       1540       -1                                  A.S. Watson Group
# 541       1541       -1                                  A.S. Watson Group
# 542       1542       -1                                  A.S. Watson Group
# 543       1543       -1                                  A.S. Watson Group
# 544       1544       -1                                  A.S. Watson Group
# 545       1545       -1                                  A.S. Watson Group
# 546       1546       -1                                  A.S. Watson Group
# 547       1547       -1                                  A.S. Watson Group
# 548       1548       -1                                  A.S. Watson Group
# 549       1549       -1                                  A.S. Watson Group
# 550       1550       -1                                  A.S. Watson Group
# 551       1551       -1                                  A.S. Watson Group
# 552       1552       -1                               A.S. Zango Cosmetics
# 553       1553       -1                                              A.S.A
# 554       1554       -1             A.S.A. Lanchonete de Produtos Naturais
# 555       1555       -1  A.S.C. Otomotiv Temizlik Tasimacilik Turz. Tek...
# 556       1556       -1                                      A.S.D HaZayit
#
#                                                Company  \
# 695                                        A2B Trading
# 696                                     A2C Intertrade
# 697                       A2P - Alternative 2 Plastics
# 698                                  A2V Farm Organics
# 699                                                A2W
# 700                                A3 Atelier Gourmand
# 701                           A3 Cosmetic Laboratories
# 626                                         A&C Snacks
# 702                                            A3 Wine
# 704                                                A62
# 705                                            A7 Agro
# 706                                        A7B Bohemia
# 707                                             A9 Bio
# 708                                                 AA
# 709                                       AA - Doble A
# 710                                           AA Media
# 711                                        AA Skincare
# 712                                           AA Spice
# 713                                        AA. Doble A
# 714     Ação Beleza Industria e Comércio de Cosmeticos
# 715                      Ação Serviço de Empacotamento
# 716                                   Açúcar Número Um
# 703                                   A4 Fruit Trading
# 748                                  Aache Food Centre
# 625                                         A&C Snacks
# 623                                   A&C Delikatessen
# 533                               A.S. Bawazir Trading
# 534                                      A.S. Bazuhair
# 535                           A.S. Comércio de Cereais
# 536                                 A.S. Narkar & Bros
# 537                                         A.S. Trade
# 538                                       A.S. Traders
# 539                                        A.S. Watson
# 540                                           Kruidvat
# 541                                                DTS
# 542                                  A.S. Watson Group
# 543                                       ICI Paris XL
# 544                                                DTS
# 545                                       ICI Paris XL
# 546                                       Trekpleister
# 547                                            Watsons
# 548                                  A.S. Watson Group
# 549          Watson Güzellik ve Bakim Ürünleri Ticaret
# 550                                           Kruidvat
# 551                                       Trekpleister
# 552                               A.S. Zango Cosmetics
# 553                                              A.S.A
# 554             A.S.A. Lanchonete de Produtos Naturais
# 555  A.S.C. Otomotiv Temizlik Tasimacilik Turz. Tek...
# 556                                      A.S.D HaZayit
#
#                                        Company address Company county/State  \
# 695                                                NaN                  NaN
# 696          363/1 Moo 1, Tha Yang, Phetchaburi, 76130                  NaN
# 697   5 Martyn St - PO Box 461, Waiuku, Auckland, 2123                  NaN
# 698  No. 755, Channasandra, Dr. Vishnuvardhan Road,...                  NaN
# 699  7 Olufunmilola, Okikiolu off Toyin Stre., Ikej...                  NaN
# 700              4, Z.A. La Tranche, Villeneuve, 04180                  NaN
# 701                                                NaN                  NaN
# 626                 New Orleans, Louisiana (LA), 70112       Louisiana (LA)
# 702                     Napa & Lodi, California (CA),       California (CA)
# 704                                                NaN                  NaN
# 705                    Kavkazskaya 2, Orenburg, 460022                  NaN
# 706    str. Luzna 716/2, Shiran Tower, Praha 6, 160 00                  NaN
# 707    55/40, M. 6. T. Barngpumai, Samut Prakan, 10280                  NaN
# 708                                 Lembang, Bandung,                   NaN
# 709  Av. Oswaldo Guayasamín Km 21 1/2, Rosa Blanca,...                  NaN
# 710                                           RG21 4EA                  NaN
# 711           36 Cotham Hill , Cotham, Bristol, BS66LA                  NaN
# 712                       P.O. Box 606, Umkomaas, 4170                  NaN
# 713               Av. Interoceanica Km 21 1/2, Quito,                   NaN
# 714  Rua Gatolandia n. 144, Jardim Guilermino, São ...                  NaN
# 715  R Santo Ivo 291, Sala 02, Cidade Salvador, Jac...                  NaN
# 716  Rua Senador Souza Naves, 1237, Centro, PR, Ser...                  NaN
# 703  75/4 Phaholyothin Rd, Moo.11, Klong Nueng, Klo...                  NaN
# 748            44, Hampden Lane, Wellawatte, Colombo,                   NaN
# 625    37 West 8th St., New York, New York (NY), 10014        New York (NY)
# 623             Musterplatzstrasse 2, Berneck, CH-9442                  NaN
# 533                      P.O. Box 32163, Jeddah, 21328                  NaN
# 534                        Mirza Masjid General Trd.,                   NaN
# 535  Rua João Paulo I, No. 23, Alvorada, Manaus - A...                  NaN
# 536                 Kasal, Taluka: Kudal, Sindhudurg,                   NaN
# 537  Factory House 101, Road 2, Dakhingaon, Bashabo...                  NaN
# 538           374, South Paikpara, Mirpur, Dhaka, 1216                  NaN
# 539  Güzellik ve Bakim Ürünleri, Site Yolu Sokak No...                  NaN
# 540                     Nijborg 17, Renswoude, 3927 DA                  NaN
# 541                           Krasnova 27, Kyiv, 03115                  NaN
# 542  Watson House 1-5, Wo Liu Hang Road, Shatin, N....                  NaN
# 543                                    Vilvoorde, 1800                  NaN
# 544          Prov. Okhtyrs'kyy 7, Korp. 3, Kyiv, 03680                  NaN
# 545                                        Renswoude,                   NaN
# 546                     Nijborg 17, Renswoude, 3927 DA                  NaN
# 547  In. Okhtyrka 7, Building 3, Office 3/203, Kyiv...                  NaN
# 548                                                NaN                  NaN
# 549  Site Yolu Sokak No. 5 Anel Is Merkezi, Kat:4, ...                  NaN
# 550                           Meir 21, Antwerpen, 2000                  NaN
# 551                                          Heteren,                   NaN
# 552  No. 47 Small Scale Industrial Area, Sharada Ph...                  NaN
# 553  Part., 39/9 Moo.1 Bang Nam Jed, Muang,, Samuts...                  NaN
# 554  Rua Sacadura Cabral, 79, Saúde, RJ, Rio de Jan...                  NaN
# 555  Macun Mah. Bagdat Cad. M. Emin Erdogan Is Merk...                  NaN
# 556                          POB 9, Park Shahak, 37862                  NaN
#
#         Company Territory                   Website  \
# 695                   NaN                       NaN
# 696              Thailand                       NaN
# 697           New Zealand              www.a2p.shop
# 698                 India                       NaN
# 699               Nigeria                       NaN
# 700                France                       NaN
# 701                 Italy                       NaN
# 626                   USA                       NaN
# 702                   USA                       NaN
# 704          South Africa                       NaN
# 705                Russia                       NaN
# 706        Czech Republic                www.a7b.cz
# 707              Thailand                       NaN
# 708             Indonesia                       NaN
# 709               Ecuador                       NaN
# 710                    UK      http://www.theaa.com
# 711                    UK                       NaN
# 712          South Africa                       NaN
# 713               Ecuador  dobleaproducts@gmail.com
# 714                Brazil                       NaN
# 715                Brazil                       NaN
# 716                Brazil      www.moinhoglobo.comn
# 703              Thailand                       NaN
# 748             Sri Lanka                       NaN
# 625                   USA                       NaN
# 623           Switzerland                       NaN
# 533          Saudi Arabia                       NaN
# 534  United Arab Emirates                       NaN
# 535                Brazil                       NaN
# 536                 India                       NaN
# 537            Bangladesh                       NaN
# 538            Bangladesh                       NaN
# 539                Turkey        www.watsons.com.tr
# 540           Netherlands           www.kruidvat.nl
# 541               Ukraine                       NaN
# 542             Hong Kong                       NaN
# 543               Belgium                       NaN
# 544               Ukraine                       NaN
# 545           Netherlands                       NaN
# 546           Netherlands       www.trekpleister.nl
# 547               Ukraine                       NaN
# 548                   NaN                       NaN
# 549                Turkey                       NaN
# 550               Belgium           www.kruidvat.be
# 551           Netherlands                       NaN
# 552               Nigeria                       NaN
# 553              Thailand         www.miraclepi.com
# 554                Brazil                       NaN
# 555                Turkey                       NaN
# 556                Israel                       NaN
#
#                                      CompanyName_clean
# 695                                        a2b trading
# 696                                     a2c intertrade
# 697                         a2p alternative 2 plastics
# 698                                  a2v farm organics
# 699                                                a2w
# 700                                a3 atelier gourmand
# 701                           a3 cosmetic laboratories
# 626                                           c snacks
# 702                                            a3 wine
# 704                                                a62
# 705                                            a7 agro
# 706                                        a7b bohemia
# 707                                             a9 bio
# 708                                                 aa
# 709                                           aa doble
# 710                                           aa media
# 711                                        aa skincare
# 712                                           aa spice
# 713                                           aa doble
# 714     ação beleza industria e comércio de cosmeticos
# 715                      ação serviço de empacotamento
# 716                                   açúcar número um
# 703                                   a4 fruit trading
# 748                                  aache food centre
# 625                                           c snacks
# 623                                     c delikatessen
# 533                                    bawazir trading
# 534                                           bazuhair
# 535                                comércio de cereais
# 536                                        narkar bros
# 537                                              trade
# 538                                            traders
# 539                                             watson
# 540                                       watson group
# 541                                       watson group
# 542                                       watson group
# 543                                       watson group
# 544                                       watson group
# 545                                       watson group
# 546                                       watson group
# 547                                       watson group
# 548                                       watson group
# 549                                       watson group
# 550                                       watson group
# 551                                       watson group
# 552                                    zango cosmetics
# 553
# 554                    lanchonete de produtos naturais
# 555  c otomotiv temizlik tasimacilik turz teks gida...
# 556                                            hazayit

# %%
# putting everything together and creating standard names!
def standard_name():
    d_standard_name = {}
    for cluster in df_eval.cluster.unique():
        names = df_eval[df_eval['cluster']==cluster].CompanyName_clean.to_list()
        l_common_substring = []
        if len(names) > 1:
            for i in range(0, len(names)):
                for j in range(i+1, len(names)):
                    seqMatch = SequenceMatcher(None, names[i], names[j])
                    match = seqMatch.find_longest_match(0, len(names[i]), 0, len(names(j)))
                    if (match.size!=0) :
                        l_common_substring.append(names[i][match.a]: match.a + match.size].strip())
            n = len(l_common_substring)
            counts = Counter(l_common_substring)
            get_mode = dict(counts)
            mode = [k for k, v in get_mode.items() if v == max(list(counts.values()))]
            d_standard_name[cluster] = ';'.join(mode)
            
        else:
            d_standard_name[cluster] = names[0]
            
    df_standard_names = pd.DataFrame(list(d_standard_name.items()), columns = ['cluster', 'StandardName'])
